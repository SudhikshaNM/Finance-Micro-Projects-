# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

tickers = ["GC=F","^GSPC","^IXIC","CL=F","BTC-USD","TLT"]
data = yf.download(tickers, period="6mo", auto_adjust=True)['Close']

returns = data.pct_change()
corr = returns.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap Across Asset Classes")
plt.show()
# Out:
# [*********************100%***********************]  6 of 6 completed
# C:\Users\Sudhiksha N M\AppData\Local\Temp\ipykernel_31316\26341927.py:9: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data.pct_change()
